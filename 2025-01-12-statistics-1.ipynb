# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics as stats

# %%
data = np.linspace(0, 10, 100)

# %%
data1 = np.random.randn(10000)

# %%
data
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
data1
# Out:
# array([ 0.17269185, -0.08733071, -0.61036286, ..., -0.51639733,
#        -0.07034452, -0.64685507], shape=(10000,))

# %%
np.mean(data1)
# Out:
# np.float64(-0.00016942101210818094)

# %%
np.median(data1)
# Out:
# np.float64(0.007797452651011217)

# %%
stats.mode(data1)
# Out:
# np.float64(0.17269185297758147)

# %%
np.std(data1)
# Out:
# np.float64(0.9896671339099137)

# %%
np.mean(data)
# Out:
# np.float64(5.0)

# %%
np.median(data)
# Out:
# np.float64(5.0)

# %%
stats.mode(data)
# Out:
# np.float64(0.0)

# %%
np.std(data)
# Out:
# np.float64(2.9157646512850626)

# %% [markdown]
# ## PDF - Probability Density Function

# %%
norm.pdf(data)
# Out:
# array([3.98942280e-01, 3.96912251e-01, 3.90883931e-01, 3.81039507e-01,
#        3.67672436e-01, 3.51172916e-01, 3.32008980e-01, 3.10704486e-01,
#        2.87815442e-01, 2.63906165e-01, 2.39526659e-01, 2.15192461e-01,
#        1.91367915e-01, 1.68453513e-01, 1.46777638e-01, 1.26592680e-01,
#        1.08075230e-01, 9.13298239e-02, 7.63955298e-02, 6.32546052e-02,
#        5.18424154e-02, 4.20578610e-02, 3.37736510e-02, 2.68458845e-02,
#        2.11225477e-02, 1.64506763e-02, 1.26820683e-02, 9.67754721e-03,
#        7.30986545e-03, 5.46540492e-03, 4.04486639e-03, 2.96315857e-03,
#        2.14869355e-03, 1.54227900e-03, 1.09577221e-03, 7.70631042e-04,
#        5.36465244e-04, 3.69662637e-04, 2.52138056e-04, 1.70231576e-04,
#        1.13765535e-04, 7.52575687e-05, 4.92786192e-05, 3.19400618e-05,
#        2.04918821e-05, 1.30135811e-05, 8.18051551e-06, 5.09018302e-06,
#        3.13512599e-06, 1.91137312e-06, 1.15346608e-06, 6.89021948e-07,
# ...

# %%
plt.figure(figsize=(10, 10))
plt.plot(data, norm.pdf(data))

# %%
plt.scatter(data, norm.pdf(data))

# %%
plt.figure(figsize=(10, 10))
plt.plot(data1, norm.pdf(data1))

# %%
plt.scatter(data1, norm.pdf(data1))

# %% [markdown]
# ### If data falls under Standard Normal Distribution, it's mostly right data and is good to apply for most of the ML models. We don't need to normalise the datasets.
